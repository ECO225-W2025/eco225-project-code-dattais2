# %% [markdown]
# # First Code
# Just getting summary statistics for my datasets.

# %%
# install random packages
# %pip install qeds
import random
import numpy as np
import pandas as pd
import qeds
import matplotlib.pyplot as plt

# %matplotlib inline
# activate plot theme
import qeds
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# make Dataframes
public_df = pd.read_csv("Public_Schools.csv")
private_df = pd.read_csv("Private_Schools.csv")

# %%
public_summ = public_df.describe()
private_summ = private_df.describe()
display(public_summ)
display(private_summ)
# Out:
#                   X             Y       OBJECTID        NCESID            ZIP  \
# count  1.023340e+05  1.023340e+05  102334.000000  1.023340e+05  102334.000000
# mean  -1.033332e+07  4.579500e+06   51167.500000  2.905037e+11   53562.284295
# std    1.886464e+06  8.304702e+05   29541.425561  1.673239e+11   29196.306387
# min   -1.966346e+07 -1.613688e+06       1.000000  1.000050e+10     601.000000
# 25%   -1.123582e+07  4.020111e+06   25584.250000  1.302550e+11   30025.750000
# 50%   -9.926529e+06  4.687048e+06   51167.500000  2.906120e+11   54937.000000
# 75%   -9.017748e+06  5.113090e+06   76750.750000  4.218990e+11   78521.000000
# max    1.613220e+07  1.150574e+07  102334.000000  7.800030e+11   99950.000000
#
#                 TYPE         STATUS     POPULATION     COUNTYFIPS  \
# count  102334.000000  102334.000000  102334.000000  102334.000000
# mean        1.220054       1.090947     483.036889   28968.553599
# std         0.734473       0.579796     560.475983   16728.169028
# ...
